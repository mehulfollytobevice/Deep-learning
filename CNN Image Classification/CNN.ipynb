# %% [markdown]
# #Importing and Unzipping the dataset

# %%
# !unzip "/content/gdrive/My Drive/P14-Convolutional-Neural-Networks.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.235.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.235.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2350.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2350.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2351.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2351.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2352.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2352.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2353.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2353.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2354.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2354.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2355.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2355.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2356.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2356.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2357.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2357.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2358.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2358.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2359.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2359.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.236.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.236.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2360.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2360.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2361.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2361.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2362.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2362.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2363.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2363.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2364.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2364.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2365.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2365.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2366.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2366.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2367.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2367.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2368.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2368.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2369.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2369.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.237.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.237.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2370.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2370.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2371.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2371.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2372.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2372.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2373.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2373.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2374.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2374.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2375.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2375.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2376.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2376.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2377.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2377.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2378.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2378.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2379.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2379.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.238.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.238.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2380.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2380.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2381.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2381.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2382.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2382.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2383.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2383.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2384.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2384.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2385.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2385.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2386.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2386.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2387.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2387.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2388.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2388.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2389.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2389.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.239.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.239.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2390.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2390.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2391.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2391.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2392.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2392.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2393.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2393.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2394.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2394.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2395.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2395.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2396.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2396.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2397.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2397.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2398.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2398.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2399.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2399.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.24.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.24.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.240.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.240.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2400.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2400.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2401.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2401.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2402.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2402.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2403.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2403.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2404.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2404.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2405.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2405.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2406.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2406.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2407.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2407.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2408.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2408.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2409.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2409.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.241.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.241.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2410.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2410.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2411.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2411.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2412.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2412.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2413.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2413.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2414.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2414.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2415.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2415.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2416.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2416.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2417.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2417.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2418.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2418.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2419.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2419.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.242.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.242.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2420.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2420.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2421.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2421.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2422.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2422.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2423.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2423.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2424.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2424.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2425.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2425.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2426.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2426.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2427.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2427.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2428.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2428.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2429.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2429.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.243.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.243.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2430.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2430.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2431.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2431.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2432.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2432.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2433.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2433.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2434.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2434.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2435.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2435.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2436.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2436.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2437.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2437.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2438.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2438.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2439.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2439.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.244.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.244.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2440.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2440.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2441.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2441.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2442.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2442.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2443.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2443.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2444.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2444.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2445.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2445.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2446.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2446.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2447.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2447.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2448.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2448.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2449.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2449.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.245.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.245.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2450.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2450.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2451.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2451.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2452.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2452.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2453.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2453.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2454.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2454.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2455.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2455.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2456.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2456.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2457.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2457.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2458.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2458.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2459.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2459.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.246.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.246.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2460.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2460.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2461.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2461.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2462.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2462.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2463.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2463.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2464.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2464.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2465.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2465.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2466.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2466.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2467.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2467.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2468.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2468.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2469.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2469.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.247.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.247.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2470.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2470.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2471.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2471.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2472.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2472.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2473.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2473.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2474.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2474.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2475.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2475.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2476.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2476.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2477.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2477.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2478.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2478.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2479.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2479.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.248.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.248.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2480.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2480.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2481.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2481.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2482.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2482.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2483.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2483.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2484.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2484.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2485.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2485.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2486.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2486.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2487.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2487.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2488.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2488.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2489.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2489.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.249.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.249.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2490.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2490.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2491.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2491.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2492.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2492.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2493.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2493.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2494.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2494.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2495.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2495.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2496.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2496.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2497.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2497.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2498.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2498.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2499.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2499.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.25.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.25.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.250.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.250.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2500.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2500.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2501.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2501.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2502.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2502.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2503.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2503.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2504.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2504.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2505.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2505.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2506.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2506.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2507.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2507.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2508.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2508.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2509.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2509.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.251.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.251.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2510.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2510.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2511.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2511.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2512.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2512.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2513.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2513.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2514.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2514.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2515.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2515.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2516.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2516.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2517.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2517.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2518.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2518.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2519.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2519.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.252.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.252.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2520.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2520.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2521.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2521.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2522.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2522.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2523.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2523.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2524.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2524.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2525.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2525.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2526.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2526.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2527.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2527.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2528.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2528.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2529.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2529.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.253.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.253.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2530.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2530.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2531.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2531.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2532.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2532.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2533.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2533.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2534.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2534.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2535.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2535.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2536.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2536.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2537.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2537.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2538.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2538.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2539.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2539.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.254.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.254.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2540.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2540.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2541.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2541.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2542.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2542.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2543.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2543.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2544.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2544.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2545.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2545.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2546.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2546.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2547.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2547.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2548.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2548.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2549.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2549.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.255.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.255.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2550.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2550.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2551.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2551.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2552.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2552.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2553.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2553.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2554.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2554.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2555.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2555.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2556.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2556.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2557.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2557.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2558.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2558.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2559.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2559.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.256.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.256.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2560.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2560.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2561.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2561.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2562.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2562.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2563.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2563.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2564.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2564.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2565.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2565.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2566.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2566.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2567.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2567.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2568.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2568.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2569.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2569.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.257.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.257.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2570.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2570.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2571.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2571.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2572.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2572.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2573.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2573.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2574.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2574.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2575.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2575.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2576.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2576.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2577.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2577.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2578.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2578.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2579.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2579.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.258.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.258.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2580.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2580.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2581.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2581.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2582.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2582.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2583.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2583.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2584.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2584.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2585.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2585.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2586.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2586.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2587.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2587.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2588.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2588.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2589.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2589.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.259.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.259.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.2590.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.2590.jpg
# ...
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.918.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.918.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.919.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.919.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.92.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.92.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.920.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.920.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.921.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.921.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.922.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.922.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.923.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.923.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.924.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.924.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.925.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.925.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.926.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.926.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.927.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.927.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.928.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.928.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.929.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.929.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.93.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.93.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.930.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.930.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.931.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.931.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.932.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.932.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.933.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.933.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.934.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.934.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.935.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.935.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.936.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.936.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.937.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.937.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.938.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.938.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.939.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.939.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.94.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.94.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.940.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.940.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.941.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.941.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.942.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.942.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.943.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.943.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.944.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.944.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.945.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.945.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.946.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.946.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.947.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.947.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.948.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.948.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.949.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.949.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.95.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.95.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.950.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.950.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.951.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.951.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.952.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.952.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.953.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.953.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.954.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.954.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.955.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.955.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.956.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.956.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.957.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.957.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.958.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.958.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.959.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.959.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.96.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.96.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.960.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.960.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.961.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.961.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.962.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.962.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.963.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.963.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.964.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.964.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.965.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.965.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.966.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.966.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.967.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.967.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.968.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.968.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.969.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.969.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.97.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.97.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.970.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.970.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.971.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.971.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.972.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.972.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.973.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.973.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.974.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.974.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.975.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.975.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.976.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.976.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.977.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.977.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.978.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.978.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.979.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.979.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.98.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.98.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.980.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.980.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.981.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.981.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.982.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.982.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.983.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.983.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.984.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.984.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.985.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.985.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.986.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.986.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.987.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.987.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.988.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.988.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.989.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.989.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.99.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.99.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.990.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.990.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.991.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.991.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.992.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.992.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.993.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.993.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.994.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.994.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.995.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.995.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.996.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.996.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.997.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.997.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.998.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.998.jpg
#   inflating: Convolutional_Neural_Networks/dataset/training_set/dogs/dog.999.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/training_set/dogs/._dog.999.jpg
#   inflating: __MACOSX/Convolutional_Neural_Networks/dataset/._training_set

# %%
# !ls
# Out:
# cnn.py	dataset

# %% [markdown]
# #Building the neural network

# %% [markdown]
# Importing the libraries

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Convolution2D
from tensorflow.python.keras.layers import MaxPooling2D
from tensorflow.python.keras.layers import Flatten
from tensorflow.python.keras.layers import Dense

# %% [markdown]
# Initialising the neural network

# %%
classifier=Sequential()

# %% [markdown]
# Building the CNN  and adding the layers

# %% [markdown]
# Layer 1 : Convolution Layer

# %%
classifier.add(Convolution2D(32,3,3,input_shape=(64,64,3),activation='relu'))

# %% [markdown]
# Layer 2: Max Pooling Layer

# %%
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# Layer 3,4: Adding additional layers to improve accuracy

# %%
#Here we do not need to add the input shape ,since the input is not images but feature maps ,
#so Keras will know the size of the input feature maps
classifier.add(Convolution2D(32,3,3,activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# Layer 5: Flattening Layer

# %%
classifier.add(Flatten())

# %% [markdown]
# Layer 6: Classic ANN Layer(Full Connection)

# %%
classifier.add(Dense(128,activation='relu'))
classifier.add(Dense(1,activation='sigmoid'))
#the output layer has only one node , since the output is binary (there are only 2 categories)

# %% [markdown]
# Compiling the CNN

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #Image Pre-processing

# %% [markdown]
# ###Data Augmentation for generalisation and preventing over-fitting
# Data augmentation is a strategy that enables practitioners to significantly increase the diversity of data available for training models, without actually collecting new data. Data augmentation techniques such as cropping, padding, and horizontal flipping are commonly used to train large neural networks.

# %%
#We create two seperate objects of the ImageDataGenerator class one for the training set and one for the test set
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

#feature scaling 
test_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# Augmenting and creating training set

# %%
training_set = train_datagen.flow_from_directory(
        'dataset/training_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# Augmenting and creating test set

# %%
test_set = test_datagen.flow_from_directory(
        'dataset/test_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ####Notes:
# 1. Since the data augmentation is random ,it reduces the chances for overfitting ,since no two images are the same.
# 2.Data augmentation happens in batches, so a certain kind of data augmentation is applied to a batch of images.
# 3. The setup of the dataset directory is very important . Making a folder for each category proves to be extremely useful and can be directly used for data augmentation and model fitting.

# %% [markdown]
# #Fitting the model on the training set and also testing performance on test set simultaneously.

# %%
classifier.fit_generator(
        training_set,
        steps_per_epoch=8000,
        epochs=25,
        validation_data=test_set,
        validation_steps=2000)

# %% [markdown]
# ###Notes:
# 1.To increase the accuracy of the CNN , we can add more number of convolutional layes to the network ,or tweek the parameters of these layers.
#
# 2.Also increasing the target size of the images allows the network to capture the features more effectively and efficiently.
#
# 3.Data augmentation can be modified and more complex data augmentation operations can be applied on the dataset to increase the accuracy of the network.
